# %% [markdown]
# # データ準備する
# azuremlのデータを扱うために必要なazureml-dataprep等をインストールする(公式チュートリアルのままだとバージョンの整合性が合わないため、 `--ignore-installed` オプションを利用している)

# %%
# !pip install --ignore-installed azureml-dataprep azureml-sdk[automl,notebooks] matplotlib certifi
# Out:
# Collecting azureml-dataprep
#   Downloading https://files.pythonhosted.org/packages/82/ab/ce732bc6a11cf52614f438b5b077c449121a66f512032981b1df773e710d/azureml_dataprep-1.0.16-py3-none-any.whl (24.9MB)
#     100% |████████████████████████████████| 24.9MB 11kB/s eta 0:00:01   7% |██▍                             | 1.8MB 8.8MB/s eta 0:00:03    15% |█████                           | 3.9MB 1.0MB/s eta 0:00:22kB/s eta 0:00:24    34% |██████████▉                     | 8.5MB 2.0MB/s eta 0:00:09    61% |███████████████████▋            | 15.3MB 1.7MB/s eta 0:00:06    71% |███████████████████████         | 17.9MB 1.5MB/s eta 0:00:05    84% |███████████████████████████     | 21.0MB 1.7MB/s eta 0:00:03
# Collecting azureml-sdk[automl,notebooks]
#   Downloading https://files.pythonhosted.org/packages/b3/77/e73a59a701a0f81ce9555c529dae6c4235b0d7ddd8beeecaa8e6024df623/azureml_sdk-1.0.17-py3-none-any.whl
# Collecting matplotlib
#   Downloading https://files.pythonhosted.org/packages/89/61/465fb3bfba684b0f53b5c4829c3c89e86e6fe9fdcdfda93e38f1788090f0/matplotlib-3.0.3-cp35-cp35m-manylinux1_x86_64.whl (13.0MB)
#     100% |████████████████████████████████| 13.0MB 12kB/s  eta 0:00:01   26% |████████▋                       | 3.5MB 6.4MB/s eta 0:00:02B 36.2MB/s eta 0:00:01
# Collecting certifi
#   Using cached https://files.pythonhosted.org/packages/9f/e0/accfc1b56b57e9750eba272e24c4dddeac86852c2bebd1236674d7887e8a/certifi-2018.11.29-py2.py3-none-any.whl
# Collecting numpy>=1.11.3 (from azureml-dataprep)
#   Downloading https://files.pythonhosted.org/packages/e3/18/4f013c3c3051f4e0ffbaa4bf247050d6d5e527fe9cb1907f5975b172f23f/numpy-1.16.2-cp35-cp35m-manylinux1_x86_64.whl (17.2MB)
#     100% |████████████████████████████████| 17.2MB 14kB/s eta 0:00:011        | 4.3MB 49.0MB/s eta 0:00:01    54% |█████████████████▍              | 9.4MB 36.9MB/s eta 0:00:01
# Collecting pandas>=0.19.2 (from azureml-dataprep)
#   Downloading https://files.pythonhosted.org/packages/e2/a3/c42cd52e40527ba35aed53a988c485ffeddbae0722b8b756da82464baa73/pandas-0.24.1-cp35-cp35m-manylinux1_x86_64.whl (10.0MB)
#     100% |████████████████████████████████| 10.0MB 18kB/s eta 0:00:01    52% |█████████████████               | 5.3MB 12.0MB/s eta 0:00:01:00:01    87% |████████████████████████████    | 8.8MB 1.6MB/s eta 0:00:01��██████████████████████████▉  | 9.4MB 3.0MB/s eta 0:00:01
# Collecting dotnetcore2==2.1.7 (from azureml-dataprep)
#   Downloading https://files.pythonhosted.org/packages/5e/ad/563e291f291ddae9967fc6347b5240e5ee5fdb173c33e0780c30ca8cd4c2/dotnetcore2-2.1.7-py3-none-manylinux1_x86_64.whl (28.7MB)
#     100% |████████████████████████████████| 28.7MB 8.6kB/s ta 0:00:011       | 8.3MB 47.7MB/s eta 0:00:01         | 10.7MB 2.5MB/s eta 0:00:0812.3MB 4.9MB/s eta 0:00:04      | 15.2MB 1.9MB/s eta 0:00:08[K    57% |██████████████████▎             | 16.4MB 4.6MB/s eta 0:00:03       | 17.7MB 1.4MB/s eta 0:00:08��████████████▍           | 18.3MB 2.6MB/s eta 0:00:05 68% |█████████████████████▉          | 19.6MB 5.9MB/s eta 0:00:021MB 3.2MB/s eta 0:00:03��█████████████████▍       | 21.9MB 7.7MB/s eta 0:00:01ta 0:00:01    | 24.3MB 3.7MB/s eta 0:00:02��██████████    | 25.0MB 1.8MB/s eta 0:00:03:01████████▊| 28.4MB 3.5MB/s eta 0:00:01
# Collecting azureml-dataprep-native<12.0.0,>=11.2.2 (from azureml-dataprep)
#   Downloading https://files.pythonhosted.org/packages/54/3b/7e51f60c1a9e3440171fad38b9227bc3954ebf7f4724965bf222f60f0467/azureml_dataprep_native-11.2.2-cp35-cp35m-manylinux1_x86_64.whl (1.3MB)
#     100% |████████████████████████████████| 1.4MB 5.6MB/s eta 0:00:01
# Collecting azureml-train==1.0.17.* (from azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/cc/93/e0e72a2cfa22aa9eff29eb458507b6b80f97bd9901413491388793842d47/azureml_train-1.0.17-py3-none-any.whl
# Collecting azureml-pipeline==1.0.17.* (from azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/b7/f0/51b3550a651b741335d9c08603480c13eab1a96bc2483bd5f5e2107e93b8/azureml_pipeline-1.0.17-py3-none-any.whl
# Collecting azureml-core==1.0.17.* (from azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/54/8e/4e57078e34ce48d089c5e427327ebdb7a5002d807140a90948c3635bfc2e/azureml_core-1.0.17.1-py2.py3-none-any.whl (719kB)
#     100% |████████████████████████████████| 727kB 3.7MB/s ta 0:00:011
# Collecting azureml-train-automl==1.0.17.*; extra == "automl" (from azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/7e/47/f4c08c55eb32884409257008e09709b725eedf754a3fd6599addc396e760/azureml_train_automl-1.0.17.1-py3-none-any.whl (369kB)
#     100% |████████████████████████████████| 378kB 5.5MB/s eta 0:00:01
# Collecting azureml-widgets==1.0.17.*; extra == "notebooks" (from azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/1e/41/3845b973c744b6314a1e124a81273e6064abcdbf156f40c7296ab7060be5/azureml_widgets-1.0.17-py3-none-any.whl (2.5MB)
#     100% |████████████████████████████████| 2.5MB 3.4MB/s eta 0:00:01
# Collecting azureml-contrib-notebook==1.0.17.*; extra == "notebooks" (from azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/a6/a9/50ef0f07e36b72a63cba89c6c5fa95516c664ea3eb20c621b9a84e7f7245/azureml_contrib_notebook-1.0.17-py2.py3-none-any.whl
# Collecting python-dateutil>=2.1 (from matplotlib)
#   Using cached https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/de/0a/001be530836743d8be6c2d85069f46fecf84ac6c18c7f5fb8125ee11d854/pyparsing-2.3.1-py2.py3-none-any.whl (61kB)
#     100% |████████████████████████████████| 71kB 5.8MB/s eta 0:00:01
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading https://files.pythonhosted.org/packages/7e/31/d6fedd4fb2c94755cd101191e581af30e1650ccce7a35bddb7930fed6574/kiwisolver-1.0.1-cp35-cp35m-manylinux1_x86_64.whl (949kB)
#     100% |████████████████████████████████| 952kB 1.1MB/s ta 0:00:011�████████████████ | 921kB 7.4MB/s eta 0:00:01
# Collecting pytz>=2011k (from pandas>=0.19.2->azureml-dataprep)
#   Using cached https://files.pythonhosted.org/packages/61/28/1d3920e4d1d50b19bc5d24398a7cd85cc7b9a75a490570d5a30c57622d34/pytz-2018.9-py2.py3-none-any.whl
# Collecting distro>=1.2.0 (from dotnetcore2==2.1.7->azureml-dataprep)
#   Downloading https://files.pythonhosted.org/packages/ea/35/82f79b92fa4d937146c660a6482cee4f3dfa1f97ff3d2a6f3ecba33e712e/distro-1.4.0-py2.py3-none-any.whl
# Collecting azureml-train-core==1.0.17.* (from azureml-train==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/13/6e/cfec5927a693740de14da628f8dbbecb13bb19dad69c6f0a91b096cd93e2/azureml_train_core-1.0.17-py3-none-any.whl
# Collecting azureml-pipeline-steps==1.0.17.* (from azureml-pipeline==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/84/11/2327615b63a430b4aa4634c638901772f8124db4c551b2e860bd15e48f15/azureml_pipeline_steps-1.0.17-py3-none-any.whl
# Collecting azureml-pipeline-core==1.0.17.* (from azureml-pipeline==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/b1/3b/a57705bd68d37ee35ece2d929e57f41d60d02c7bd5c957bf9256fcc7b97d/azureml_pipeline_core-1.0.17-py3-none-any.whl (132kB)
#     100% |████████████████████████████████| 133kB 2.2MB/s ta 0:00:01
# Collecting paramiko>=2.0.8 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/cf/ae/94e70d49044ccc234bfdba20114fa947d7ba6eb68a2e452d89b920e62227/paramiko-2.4.2-py2.py3-none-any.whl (193kB)
#     100% |████████████████████████████████| 194kB 2.6MB/s ta 0:00:01
# Collecting SecretStorage (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/82/59/cb226752e20d83598d7fdcabd7819570b0329a61db07cfbdd21b2ef546e3/SecretStorage-3.1.1-py3-none-any.whl
# Collecting ruamel.yaml<=0.15.51,>=0.15.35 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/45/34/4818c6936fbe2a8dbda9430eb50d7e2e035e24db0ee5b232c68c54cb0c44/ruamel.yaml-0.15.51-cp35-cp35m-manylinux1_x86_64.whl (620kB)
#     100% |████████████████████████████████| 624kB 643kB/s ta 0:00:011��████████████▏                  | 256kB 2.8MB/s eta 0:00:01
# Collecting pyopenssl (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/01/c8/ceb170d81bd3941cbeb9940fc6cc2ef2ca4288d0ca8929ea4db5905d904d/pyOpenSSL-19.0.0-py2.py3-none-any.whl (53kB)
#     100% |████████████████████████████████| 61kB 7.5MB/s eta 0:00:01
# Collecting pyyaml>=3.13 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/9e/a3/1d13970c3f36777c583f136c136f804d70f500168edc1edea6daa7200769/PyYAML-3.13.tar.gz (270kB)
#     100% |████████████████████████████████| 276kB 1.2MB/s ta 0:00:01 256kB 3.7MB/s eta 0:00:01
# Collecting requests>=2.19.1 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/d9/87/ab44b9d9627ff91825ba5f5a39092ebfe97a90679008609db4c479036591/azure_mgmt_storage-3.1.1-py2.py3-none-any.whl (696kB)
#     100% |████████████████████████████████| 706kB 3.1MB/s ta 0:00:011
# Collecting pathspec (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/84/2a/bfee636b1e2f7d6e30dd74f49201ccfa5c3cf322d44929ecc6c137c486c5/pathspec-0.5.9.tar.gz
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/98/71/e632e222f34632e0527dd41799f7847305e701f38f512d81bdf96009bca4/cryptography-2.5-cp34-abi3-manylinux1_x86_64.whl (2.4MB)
#     100% |████████████████████████████████| 2.4MB 2.4MB/s eta 0:00:01
# Collecting backports.tempfile (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting docker (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/7e/3c/b610f22b170b0f8fe4d8f78974878e116562389f666f99e6549567eb9d87/docker-3.7.0-py2.py3-none-any.whl (133kB)
#     100% |████████████████████████████████| 143kB 4.6MB/s eta 0:00:01
# Collecting azure-common>=1.1.12 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/c3/f8/46248b201fd38b7e93c6da644e2fc3bc5a39118f253562751fd295a8cc77/azure_common-1.1.18-py2.py3-none-any.whl
# Collecting urllib3>=1.23 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/62/00/ee1d7de624db8ba7090d1226aebefab96a2c71cd5cfa7629d6ad3f61b79e/urllib3-1.24.1-py2.py3-none-any.whl
# Collecting PyJWT (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting azure-mgmt-keyvault>=0.40.0 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/49/de/0d69aedae7c5f6428314640b65947203ab80409c12b5d4e66fb5b7a4182e/azure_mgmt_keyvault-1.1.0-py2.py3-none-any.whl (111kB)
#     100% |████████████████████████████████| 112kB 6.9MB/s eta 0:00:01
# Collecting six>=1.11.0 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Collecting ndg-httpsclient (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting contextlib2 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/a2/71/8273a7eeed0aff6a854237ab5453bc9aa67deb49df4832801c21f0ff3782/contextlib2-0.5.5-py2.py3-none-any.whl
# Collecting msrest>=0.5.1 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/eb/96/1cf56e4cfd221b7f6eb6ab096dc23b0d21361393f0784276531e49b0b2a1/msrest-0.6.4-py2.py3-none-any.whl (81kB)
#     100% |████████████████████████████████| 81kB 2.8MB/s ta 0:00:011
# Collecting azure-mgmt-resource>=1.2.1 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/2b/2e/e79a278bedfc21308ab0c632759cfda5d7ff02d62260bcc4632449937dcf/azure_mgmt_resource-2.1.0-py2.py3-none-any.whl (757kB)
#     100% |████████████████████████████████| 757kB 1.4MB/s ta 0:00:011
# Collecting azure-mgmt-authorization>=0.40.0 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/a1/71/9a20913e92771b3c23564f1bea54d376d09fb30a75585087c70b769d75c8/azure_mgmt_authorization-0.51.1-py2.py3-none-any.whl (111kB)
#     100% |████████████████████████████████| 112kB 1.9MB/s ta 0:00:01
# Collecting jmespath (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
# Collecting azure-mgmt-containerregistry>=2.0.0 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/7a/4b/06040d992f93531e32c5f7cf7884f3edfec11f76f802dd9224c1116c3129/azure_mgmt_containerregistry-2.7.0-py2.py3-none-any.whl (509kB)
#     100% |████████████████████████████████| 512kB 5.4MB/s eta 0:00:01
# Collecting msrestazure>=0.4.33 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/46/ba/7870308e3d3b4b3956880eed2df20669a5690436793e6fc1442c8b73e01c/msrestazure-0.6.0-py2.py3-none-any.whl
# Collecting azure-graphrbac>=0.40.0 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/da/a8/3d3d6fe8458b2b07bad10195c79928ea9ba87b5cc0c08903b387dd27c6f0/azure_graphrbac-0.53.0-py2.py3-none-any.whl (108kB)
#     100% |████████████████████████████████| 112kB 3.9MB/s ta 0:00:01
# Collecting jsonpickle (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/dc/12/8c44eabb501e2bc0aec0dd152b328074d98a50968d3a02be28f6037f0c6a/jsonpickle-1.1-py2.py3-none-any.whl
# Collecting adal>=1.2.0 (from azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/00/72/53dce9e4f5d6c1aa57b8d408cb34dff1969ecbf10ab7e678f32c5e0e2397/adal-1.2.1-py2.py3-none-any.whl (52kB)
#     100% |████████████████████████████████| 61kB 2.1MB/s ta 0:00:011
# Collecting scikit-learn==0.19.1 (from azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/bf/53/8c9c950a3cfaec16069df196c0b76ab05b3d1f0527f6bb97a30f4dda5240/scikit_learn-0.19.1-cp35-cp35m-manylinux1_x86_64.whl (12.2MB)
#     99% |████████████████████████████████| 12.2MB 43.3MB/s eta 0:00:015.7MB/s eta 0:00:01 2.9MB 4.4MB/s eta 0:00:0300:04█████████                 | 5.7MB 9.2MB/s eta 0:00:010:01████████▎          | 8.1MB 2.0MB/s eta 0:00:030:01�██████████████        | 9.1MB 9.8MB/s eta 0:00:01�█████████████████████▌     | 10.1MB 6.7MB/s eta 0:00:01.1MB/s eta 0:00:01    100% |████████████████████████████████| 12.2MB 22kB/s
# Collecting scipy<=1.1.0,>=1.0.0 (from azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/cd/32/5196b64476bd41d596a8aba43506e2403e019c90e1a3dfc21d51b83db5a6/scipy-1.1.0-cp35-cp35m-manylinux1_x86_64.whl (33.1MB)
#     100% |████████████████████████████████| 33.1MB 6.0kB/s ta 0:00:011   21% |███████                         | 7.2MB 9.8MB/s eta 0:00:0311.0MB/s eta 0:00:03                      | 10.2MB 3.4MB/s eta 0:00:072.2MB/s eta 0:00:02          | 12.4MB 3.9MB/s eta 0:00:06    41% |█████████████▏                  | 13.6MB 3.6MB/s eta 0:00:06:00:02         | 17.2MB 11.2MB/s eta 0:00:02███▉            | 20.5MB 10.6MB/s eta 0:00:02   69% |██████████████████████▏         | 22.9MB 2.9MB/s eta 0:00:04████████▋         | 23.4MB 10.6MB/s eta 0:00:01�███████████████████▎        | 24.1MB 8.4MB/s eta 0:00:02███████████████████▎       | 25.1MB 4.0MB/s eta 0:00:02�██████████████████▋       | 25.5MB 8.8MB/s eta 0:00:01:00:01�██▎     | 27.1MB 7.1MB/s eta 0:00:01��██████████████████████     | 27.9MB 3.5MB/s eta 0:00:02�███████████████████████████    | 28.9MB 8.8MB/s eta 0:00:01�███████████████████▉   | 29.8MB 7.0MB/s eta 0:00:01��██▎  | 30.3MB 11.4MB/s eta 0:00:01| 31.5MB 41.3MB/s eta 0:00:012.0MB 1.6MB/s eta 0:00:01
# Collecting sklearn-pandas<=1.7.0,>=1.4.0 (from azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/7e/9c/c94f46b40b86d2c77c46c4c1b858fc66c117b4390665eca28f2e0812db45/sklearn_pandas-1.7.0-py2.py3-none-any.whl
# Collecting dill>=0.2.8 (from azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/fe/42/bfe2e0857bc284cbe6a011d93f2a9ad58a22cb894461b199ae72cfef0f29/dill-0.2.9.tar.gz (150kB)
#     100% |████████████████████████████████| 153kB 7.8MB/s ta 0:00:01
# Collecting azureml-telemetry==1.0.17.* (from azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/3b/82/7be815ca28d581332a3b8dd414af2b6a3c54ca6c520b16c9073766afb0c6/azureml_telemetry-1.0.17-py3-none-any.whl
# Collecting wheel==0.30.0 (from azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/0c/80/16a85b47702a1f47a63c104c91abdd0a6704ee8ae3b4ce4afc49bc39f9d9/wheel-0.30.0-py2.py3-none-any.whl (49kB)
#     100% |████████████████████████████████| 51kB 2.5MB/s ta 0:00:01
# Collecting tensorflow<=1.12.0,>=1.10.0 (from azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/b1/ad/48395de38c1e07bab85fc3bbec045e11ae49c02a4db0100463dd96031947/tensorflow-1.12.0-cp35-cp35m-manylinux1_x86_64.whl (83.1MB)
#     100% |████████████████████████████████| 83.1MB 3.6kB/s eta 0:00:01    13% |████▎                           | 11.1MB 13.0MB/s eta 0:00:06    16% |█████▏                          | 13.5MB 35.1MB/s eta 0:00:027��                        | 20.6MB 12.6MB/s eta 0:00:05                  | 25.3MB 1.7MB/s eta 0:00:34    33% |██████████▋                     | 27.6MB 5.0MB/s eta 0:00:12         | 29.4MB 1.9MB/s eta 0:00:28                   | 31.3MB 8.5MB/s eta 0:00:07��█████████▉                   | 33.2MB 3.4MB/s eta 0:00:15    42% |█████████████▋                  | 35.4MB 8.5MB/s eta 0:00:06                | 36.7MB 6.2MB/s eta 0:00:08             | 37.7MB 27.7MB/s eta 0:00:02████████                 | 39.0MB 3.7MB/s eta 0:00:12   47% |███████████████▍                | 39.8MB 3.5MB/s eta 0:00:13         | 44.1MB 29.1MB/s eta 0:00:02██████████████▌              | 45.4MB 35.8MB/s eta 0:00:02��████████▊              | 46.0MB 3.2MB/s eta 0:00:12s eta 0:00:02��██▎            | 50.0MB 35.2MB/s eta 0:00:01      | 51.2MB 1.7MB/s eta 0:00:19�███████████▏          | 55.0MB 2.6MB/s eta 0:00:11   67% |█████████████████████▌          | 55.7MB 10.2MB/s eta 0:00:03  67% |█████████████████████▋          | 56.3MB 7.2MB/s eta 0:00:04[K    69% |██████████████████████▎         | 58.0MB 4.4MB/s eta 0:00:06███▌         | 58.3MB 13.6MB/s eta 0:00:02███████▌        | 61.1MB 2.3MB/s eta 0:00:10██████████████▌       | 63.6MB 31.1MB/s eta 0:00:01��████████████████████▏      | 65.2MB 43.2MB/s eta 0:00:01:00:03    82% |██████████████████████████▎     | 68.3MB 10.8MB/s eta 0:00:02   | 68.5MB 16.5MB/s eta 0:00:01��█     | 70.3MB 33.1MB/s eta 0:00:01 |███████████████████████████▎    | 70.8MB 38.5MB/s eta 0:00:01��█████████▉    | 72.2MB 11.2MB/s eta 0:00:01████████████    | 72.7MB 13.7MB/s eta 0:00:01████████▏   | 73.1MB 10.3MB/s eta 0:00:01��████████████████████▋   | 74.2MB 2.8MB/s eta 0:00:04████▊   | 74.5MB 8.8MB/s eta 0:00:01████████████████████████████▎  | 76.0MB 9.4MB/s eta 0:00:01a 0:00:01    92% |█████████████████████████████▋  | 76.9MB 3.4MB/s eta 0:00:02 eta 0:00:01████████▍ | 79.0MB 7.1MB/s eta 0:00:0101� | 80.7MB 12.9MB/s eta 0:00:01% |███████████████████████████████▏| 81.0MB 4.3MB/s eta 0:00:01    98% |███████████████████████████████▊| 82.2MB 5.9MB/s eta 0:00:01████████▊| 82.4MB 8.4MB/s eta 0:00:01
# Collecting resource>=0.1.8 (from azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/34/ad/9cd037c01c075f9a273c23557f8e71195d773d59d3881bbb26011d396c8b/Resource-0.2.1-py2.py3-none-any.whl
# Collecting lightgbm<=2.2.1,>=2.0.11 (from azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/78/7e/bc87e7951cfaa998cffaf39e6c721f5bd04efb2e139486206356edb289a5/lightgbm-2.2.1-py2.py3-none-manylinux1_x86_64.whl (1.1MB)
#     100% |████████████████████████████████| 1.1MB 4.5MB/s ta 0:00:011
# Collecting ipywidgets>=7.0.0 (from azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/30/9a/a008c7b1183fac9e52066d80a379b3c64eab535bd9d86cdc29a0b766fd82/ipywidgets-7.4.2-py2.py3-none-any.whl
# Collecting ipython (from azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/14/3b/3fcf422a99a04ee493e6a4fc3014e3c8ff484a7feed238fef68bdc285085/ipython-7.3.0-py3-none-any.whl (768kB)
#     100% |████████████████████████████████| 778kB 6.0MB/s eta 0:00:01
# Collecting setuptools (from kiwisolver>=1.0.1->matplotlib)
#   Using cached https://files.pythonhosted.org/packages/d1/6a/4b2fcefd2ea0868810e92d519dacac1ddc64a2e53ba9e3422c3b62b378a6/setuptools-40.8.0-py2.py3-none-any.whl
# Collecting azureml-train-restclients-hyperdrive==1.0.17.* (from azureml-train-core==1.0.17.*->azureml-train==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/72/76/ef517f6aa79a7af0eebb605c1e06c7e155c7c6680bf5232210cbb81b5a94/azureml_train_restclients_hyperdrive-1.0.17-py3-none-any.whl
# Collecting pyasn1>=0.1.7 (from paramiko>=2.0.8->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/7b/7c/c9386b82a25115cccf1903441bba3cbadcfae7b678a20167347fa8ded34c/pyasn1-0.4.5-py2.py3-none-any.whl (73kB)
#     100% |████████████████████████████████| 81kB 3.2MB/s ta 0:00:011
# Collecting pynacl>=1.0.1 (from paramiko>=2.0.8->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/27/15/2cd0a203f318c2240b42cd9dd13c931ddd61067809fee3479f44f086103e/PyNaCl-1.3.0-cp34-abi3-manylinux1_x86_64.whl (759kB)
#     100% |████████████████████████████████| 768kB 5.6MB/s eta 0:00:01
# Collecting bcrypt>=3.1.3 (from paramiko>=2.0.8->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/d0/79/79a4d167a31cc206117d9b396926615fa9c1fdbd52017bcced80937ac501/bcrypt-3.1.6-cp34-abi3-manylinux1_x86_64.whl (55kB)
#     100% |████████████████████████████████| 61kB 7.0MB/s ta 0:00:011
# Collecting jeepney (from SecretStorage->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/2b/f7/ff23b9b59534f501d47c327576aadda59da5b83d76ff837e6075bc325b9f/jeepney-0.4-py3-none-any.whl (59kB)
#     100% |████████████████████████████████| 61kB 3.0MB/s ta 0:00:011
# Collecting chardet<3.1.0,>=3.0.2 (from requests>=2.19.1->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
# Collecting idna<2.9,>=2.5 (from requests>=2.19.1->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl
# Collecting asn1crypto>=0.21.0 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
#     100% |████████████████████████████████| 102kB 4.1MB/s a 0:00:011
# Collecting cffi!=1.11.3,>=1.8 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/5b/44/fdae2a8f66af426055f9b6fff0b155217081eddaf08a3df79ca11fe05bda/cffi-1.12.2-cp35-cp35m-manylinux1_x86_64.whl (428kB)
#     100% |████████████████████████████████| 430kB 6.1MB/s eta 0:00:01
# Collecting backports.weakref (from backports.tempfile->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting websocket-client>=0.32.0 (from docker->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/38/54/684db2ba1b7a203602808446b8686ee786f93b4a7e080cdc440cc7e06e56/websocket_client-0.55.0-py2.py3-none-any.whl (200kB)
#     100% |████████████████████████████████| 204kB 11.0MB/s ta 0:00:01
# Collecting docker-pycreds>=0.4.0 (from docker->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting azure-mgmt-nspkg>=2.0.0 (from azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/b3/c2/af4b47845f27dc7d206ed4908b9e580f8bc94a4b2f3956a0d87c40719d90/azure_mgmt_nspkg-3.0.2-py3-none-any.whl
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.5.1->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#     100% |████████████████████████████████| 51kB 2.9MB/s ta 0:00:011
# Collecting applicationinsights (from azureml-telemetry==1.0.17.*->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/e3/c8/7848a0dd85158930b859eb8be1e38fc76a91f0a040d491723ebb356d7358/applicationinsights-0.11.7-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 3.4MB/s ta 0:00:011
# Collecting gast>=0.2.0 (from tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting keras-preprocessing>=1.0.5 (from tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/c0/bf/0315ef6a9fd3fc2346e85b0ff1f5f83ca17073f2c31ac719ab2e4da0d4a3/Keras_Preprocessing-1.0.9-py2.py3-none-any.whl (59kB)
#     100% |████████████████████████████████| 61kB 4.1MB/s eta 0:00:01
# Collecting tensorboard<1.13.0,>=1.12.0 (from tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/07/53/8d32ce9471c18f8d99028b7cef2e5b39ea8765bd7ef250ca05b490880971/tensorboard-1.12.2-py3-none-any.whl (3.0MB)
#     100% |████████████████████████████████| 3.1MB 2.4MB/s eta 0:00:01
# Collecting keras-applications>=1.0.6 (from tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/90/85/64c82949765cfb246bbdaf5aca2d55f400f792655927a017710a78445def/Keras_Applications-1.0.7-py2.py3-none-any.whl (51kB)
#     100% |████████████████████████████████| 61kB 2.7MB/s ta 0:00:011
# Collecting protobuf>=3.6.1 (from tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/f0/b4/0acb16276b92d0dabe3e97bf361b5ff9922d2071c497b92dde4741d4eeb4/protobuf-3.7.0-cp35-cp35m-manylinux1_x86_64.whl (1.2MB)
#     100% |████████████████████████████████| 1.2MB 5.8MB/s eta 0:00:01
# Collecting grpcio>=1.8.6 (from tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/0e/fd/e6696e5b115f328c382dd88414168e2b918cb7153b59dc9228d3c15e356c/grpcio-1.19.0-cp35-cp35m-manylinux1_x86_64.whl (10.8MB)
#     100% |████████████████████████████████| 10.8MB 1.1MB/s eta 0:00:01   44% |██████████████▎                 | 4.8MB 9.1MB/s eta 0:00:01█████▏       | 8.1MB 33.6MB/s eta 0:00:01 | 9.1MB 46.3MB/s eta 0:00:01
# Collecting termcolor>=1.1.0 (from tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting absl-py>=0.1.6 (from tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/31/bc/ab68120d1d89ae23b694a55fe2aece2f91194313b71f9b05a80b32d3c24b/absl-py-0.7.0.tar.gz (96kB)
#     100% |████████████████████████████████| 102kB 19.6MB/s a 0:00:01
# Collecting astor>=0.6.0 (from tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/35/6b/11530768cac581a12952a2aad00e1526b89d242d0b9f59534ef6e6a1752f/astor-0.7.1-py2.py3-none-any.whl
# Collecting python-easyconfig>=0.1.0 (from resource>=0.1.8->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/b1/86/1138081cca360a02066eedaf301d0f358c35e0e0d67572acf9d6354edca9/Python_EasyConfig-0.1.7-py2.py3-none-any.whl
# Collecting JsonSir>=0.0.2 (from resource>=0.1.8->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/aa/bf/5c00c1dafaa3ca2c32e7641d9c2c6f9d6d76e127bde00eb600333a60c5bc/JsonSir-0.0.2.tar.gz
# Collecting JsonForm>=0.0.2 (from resource>=0.1.8->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/4f/b7/b9491ba4b709d0616fab15a89f8efe4d3a7924652e1fdd4f15303e9ecdf0/JsonForm-0.0.2.tar.gz
# Collecting nbformat>=4.2.0 (from ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/da/27/9a654d2b6cc1eaa517d1c5a4405166c7f6d72f04f6e7eea41855fe808a46/nbformat-4.4.0-py2.py3-none-any.whl
# Collecting ipykernel>=4.5.1 (from ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/d8/b0/f0be5c5ab335196f5cce96e5b889a4fcf5bfe462eb0acc05cd7e2caf65eb/ipykernel-5.1.0-py3-none-any.whl (113kB)
#     100% |████████████████████████████████| 122kB 2.9MB/s ta 0:00:01
# Collecting traitlets>=4.3.1 (from ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/93/d6/abcb22de61d78e2fc3959c964628a5771e47e7cc60d53e9342e21ed6cc9a/traitlets-4.3.2-py2.py3-none-any.whl
# Collecting widgetsnbextension~=3.4.0 (from ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/8a/81/35789a3952afb48238289171728072d26d6e76649ddc8b3588657a2d78c1/widgetsnbextension-3.4.2-py2.py3-none-any.whl
# Collecting pickleshare (from ipython->azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/9a/41/220f49aaea88bc6fa6cba8d05ecf24676326156c23b991e80b3f2fc24c77/pickleshare-0.7.5-py2.py3-none-any.whl
# Collecting pygments (from ipython->azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/13/e5/6d710c9cf96c31ac82657bcfb441df328b22df8564d58d0c4cd62612674c/Pygments-2.3.1-py2.py3-none-any.whl
# Collecting decorator (from ipython->azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/f1/cd/7c8240007e9716b14679bc217a1baefa4432aa30394f7e2ec40a52b1a708/decorator-4.3.2-py2.py3-none-any.whl
# Collecting prompt-toolkit<2.1.0,>=2.0.0 (from ipython->azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/f7/a7/9b1dd14ef45345f186ef69d175bdd2491c40ab1dfa4b2b3e4352df719ed7/prompt_toolkit-2.0.9-py3-none-any.whl (337kB)
#     100% |████████████████████████████████| 337kB 6.7MB/s eta 0:00:01
# Collecting pexpect; sys_platform != "win32" (from ipython->azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/89/e6/b5a1de8b0cc4e07ca1b305a4fcc3f9806025c1b651ea302646341222f88b/pexpect-4.6.0-py2.py3-none-any.whl
# Collecting backcall (from ipython->azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/84/71/c8ca4f5bb1e08401b916c68003acf0a0655df935d74d93bf3f3364b310e0/backcall-0.1.0.tar.gz
# Collecting jedi>=0.10 (from ipython->azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/25/2b/1f188901be099d52d7b06f4d3b7cb9f8f09692c50697b139eaf6fa2928d8/jedi-0.13.3-py2.py3-none-any.whl (178kB)
#     100% |████████████████████████████████| 184kB 3.6MB/s eta 0:00:01
# Collecting pycparser (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<2.6->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
#     100% |████████████████████████████████| 163kB 8.6MB/s eta 0:00:01
# Collecting azure-nspkg>=3.0.0 (from azure-mgmt-nspkg>=2.0.0->azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/c4/0c/c562be95a9a2ed52454f598571cf300b1114d0db2aa27f5b8ed3bb9cd0c0/azure_nspkg-3.0.2-py3-none-any.whl
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.17.*->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/16/95/699466b05b72b94a41f662dc9edf87fda4289e3602ecd42d27fcaddf7b56/oauthlib-3.0.1-py2.py3-none-any.whl (142kB)
#     100% |████████████████████████████████| 143kB 6.3MB/s eta 0:00:01
# Collecting markdown>=2.6.8 (from tensorboard<1.13.0,>=1.12.0->tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/7a/6b/5600647404ba15545ec37d2f7f58844d690baf2f81f3a60b862e48f29287/Markdown-3.0.1-py2.py3-none-any.whl (89kB)
#     100% |████████████████████████████████| 92kB 4.0MB/s eta 0:00:01
# Collecting werkzeug>=0.11.10 (from tensorboard<1.13.0,>=1.12.0->tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/20/c4/12e3e56473e52375aa29c4764e70d1b8f3efa6682bef8d0aae04fe335243/Werkzeug-0.14.1-py2.py3-none-any.whl (322kB)
#     100% |████████████████████████████████| 327kB 5.6MB/s eta 0:00:01
# Collecting h5py (from keras-applications>=1.0.6->tensorflow<=1.12.0,>=1.10.0->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/4c/77/c4933e12dca0f61bcdafc207c7532e1250b8d12719459fd85132f3daa9fd/h5py-2.9.0-cp35-cp35m-manylinux1_x86_64.whl (2.8MB)
#     100% |████████████████████████████████| 2.8MB 2.5MB/s eta 0:00:01     | 614kB 12.8MB/s eta 0:00:01          | 972kB 6.4MB/s eta 0:00:01
# Collecting jsonschema (from JsonForm>=0.0.2->resource>=0.1.8->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/aa/69/df679dfbdd051568b53c38ec8152a3ab6bc533434fc7ed11ab034bf5e82f/jsonschema-3.0.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 4.4MB/s eta 0:00:01
# Collecting ipython-genutils (from nbformat>=4.2.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/fa/bc/9bd3b5c2b4774d5f33b2d544f1460be9df7df2fe42f352135381c347c69a/ipython_genutils-0.2.0-py2.py3-none-any.whl
# Collecting jupyter-core (from nbformat>=4.2.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/1d/44/065d2d7bae7bebc06f1dd70d23c36da8c50c0f08b4236716743d706762a8/jupyter_core-4.4.0-py2.py3-none-any.whl
# Collecting jupyter-client (from ipykernel>=4.5.1->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/3b/c3/3043fe9ffd140d03c9d091a056794ccdc427c56ec19b8eea74f9ea0a498f/jupyter_client-5.2.4-py2.py3-none-any.whl
# Collecting tornado>=4.2 (from ipykernel>=4.5.1->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/b1/7f/8109821ff9df1bf3519169e34646705c32ac13be6a4d51a79ed57f47686e/tornado-6.0.1.tar.gz (481kB)
#     100% |████████████████████████████████| 491kB 4.7MB/s eta 0:00:01
# Collecting notebook>=4.4.1 (from widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/76/e8/50bb66c9ea6d21be89b920fac57dca49c4a5749c5b92b4a48458dd42e659/notebook-5.7.5-py2.py3-none-any.whl (9.0MB)
#     100% |████████████████████████████████| 9.0MB 693kB/s eta 0:00:01  1% |▎                               | 92kB 4.0MB/s eta 0:00:03�████████                       | 2.5MB 4.4MB/s eta 0:00:02
# Collecting wcwidth (from prompt-toolkit<2.1.0,>=2.0.0->ipython->azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/7e/9f/526a6947247599b084ee5232e4f9190a38f398d7300d866af3ab571a5bfe/wcwidth-0.1.7-py2.py3-none-any.whl
# Collecting ptyprocess>=0.5 (from pexpect; sys_platform != "win32"->ipython->azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/d1/29/605c2cc68a9992d18dada28206eeada56ea4bd07a239669da41674648b6f/ptyprocess-0.6.0-py2.py3-none-any.whl
# Collecting parso>=0.3.0 (from jedi>=0.10->ipython->azureml-contrib-notebook==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/19/b1/522b2671cc6d134c9d3f5dfc0d02fee07cab848e908d03d2bffea78cca8f/parso-0.3.4-py2.py3-none-any.whl (93kB)
#     100% |████████████████████████████████| 102kB 1.9MB/s a 0:00:011
# Collecting pyrsistent>=0.14.0 (from jsonschema->JsonForm>=0.0.2->resource>=0.1.8->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/8c/46/4e93ab8a379d7efe93f20a0fb8a27bdfe88942cc954ab0210c3164e783e0/pyrsistent-0.14.11.tar.gz (104kB)
#     100% |████████████████████████████████| 112kB 5.6MB/s ta 0:00:01
# Collecting attrs>=17.4.0 (from jsonschema->JsonForm>=0.0.2->resource>=0.1.8->azureml-train-automl==1.0.17.*; extra == "automl"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/23/96/d828354fa2dbdf216eaa7b7de0db692f12c234f7ef888cc14980ef40d1d2/attrs-19.1.0-py2.py3-none-any.whl
# Collecting pyzmq>=13 (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/39/7a/9b98aabbde03fc4c5c38079ddec1331af3846d80c0b73bdb691a21adee9c/pyzmq-18.0.1-cp35-cp35m-manylinux1_x86_64.whl (1.0MB)
#     100% |████████████████████████████████| 1.1MB 3.2MB/s eta 0:00:01
# Collecting terminado>=0.8.1 (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/2e/20/a26211a24425923d46e1213b376a6ee60dc30bcdf1b0c345e2c3769deb1c/terminado-0.8.1-py2.py3-none-any.whl
# Collecting prometheus-client (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/4c/bd/b42db3ec90ffc6be805aad09c1cea4bb13a620d0cd4b21aaa44d13541d71/prometheus_client-0.6.0.tar.gz
# Collecting jinja2 (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/7f/ff/ae64bacdfc95f27a016a7bed8e8686763ba4d277a78ca76f32659220a731/Jinja2-2.10-py2.py3-none-any.whl
# Collecting nbconvert (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/b8/39/1e67fea74dc9577cc49f9863fe3ec824e525d1304ab6027d95a94cd586f5/nbconvert-5.4.1-py2.py3-none-any.whl
# Collecting Send2Trash (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/49/46/c3dc27481d1cc57b9385aff41c474ceb7714f7935b1247194adae45db714/Send2Trash-1.5.0-py3-none-any.whl
# Collecting MarkupSafe>=0.23 (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Downloading https://files.pythonhosted.org/packages/6e/57/d40124076756c19ff2269678de7ae25a14ebbb3f6314eb5ce9477f191350/MarkupSafe-1.1.1-cp35-cp35m-manylinux1_x86_64.whl
# Collecting pandocfilters>=1.4.1 (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/4c/ea/236e2584af67bb6df960832731a6e5325fd4441de001767da328c33368ce/pandocfilters-1.4.2.tar.gz
# Collecting entrypoints>=0.2.2 (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/ac/c6/44694103f8c221443ee6b0041f69e2740d89a25641e62fb4f2ee568f2f9c/entrypoints-0.3-py2.py3-none-any.whl
# Collecting testpath (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/be/a4/162f9ebb6489421fe46dcca2ae420369edfee4b563c668d93cb4605d12ba/testpath-0.4.2-py2.py3-none-any.whl
# Collecting mistune>=0.8.1 (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/09/ec/4b43dae793655b7d8a25f76119624350b4d65eb663459eb9603d7f1f0345/mistune-0.8.4-py2.py3-none-any.whl
# Collecting bleach (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/ab/05/27e1466475e816d3001efb6e0a85a819be17411420494a1e602c36f8299d/bleach-3.1.0-py2.py3-none-any.whl
# Collecting defusedxml (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/87/1c/17f3e3935a913dfe2a5ca85fa5ccbef366bfd82eb318b1f75dadbf0affca/defusedxml-0.5.0-py2.py3-none-any.whl
# Collecting webencodings (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->azureml-widgets==1.0.17.*; extra == "notebooks"->azureml-sdk[automl,notebooks])
#   Using cached https://files.pythonhosted.org/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl
# Building wheels for collected packages: pyyaml, pathspec, dill, gast, termcolor, absl-py, JsonSir, JsonForm, backcall, pycparser, tornado, pyrsistent, prometheus-client, pandocfilters
#   Building wheel for pyyaml (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/ad/da/0c/74eb680767247273e2cf2723482cb9c924fe70af57c334513f
#   Building wheel for pathspec (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/45/cb/7e/ce6e6062c69446e39e328170524ca8213498bc66a74c6a210b
#   Building wheel for dill (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/5b/d7/0f/e58eae695403de585269f4e4a94e0cd6ca60ec0c202936fa4a
#   Building wheel for gast (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
#   Building wheel for termcolor (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Building wheel for absl-py (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/90/db/f8/2c3101f72ef1ad434e4662853174126ce30201a3e163dcbeca
#   Building wheel for JsonSir (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/ee/30/5c/3a3b5e1386c8db9a3be5f5c3933644ae0533c1351c6a8eb4b5
#   Building wheel for JsonForm (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/e8/74/51/42c2d41c02bdc6f0e604476b7e4293b8c98d0bcbfa1dff78c8
#   Building wheel for backcall (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/98/b0/dd/29e28ff615af3dda4c67cab719dd51357597eabff926976b45
#   Building wheel for pycparser (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
#   Building wheel for tornado (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/09/a9/78/41e23ffcb122e8f4b02537f4480a276ec1ad760dd492373961
#   Building wheel for pyrsistent (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/83/59/9a/a037b9b3c3e93d9275ea0aff9d6064400f372879dfdab01afe
#   Building wheel for prometheus-client (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/4b/04/b8/3709c73e7453f311ebd46ad581b89642543213f995e2659b9e
#   Building wheel for pandocfilters (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/39/01/56/f1b08a6275acc59e846fa4c1e1b65dbc1919f20157d9e66c20
# Successfully built pyyaml pathspec dill gast termcolor absl-py JsonSir JsonForm backcall pycparser tornado pyrsistent prometheus-client pandocfilters
# luigi 2.8.3 has requirement python-dateutil==2.7.5, but you'll have python-dateutil 2.8.0 which is incompatible.
# luigi 2.8.3 has requirement tornado<5,>=4.0, but you'll have tornado 6.0.1 which is incompatible.
# azureml-train-automl 1.0.17.1 has requirement numpy<1.15.0,>=1.11.0, but you'll have numpy 1.16.2 which is incompatible.
# azureml-train-automl 1.0.17.1 has requirement pandas<=0.23.4,>=0.21.0, but you'll have pandas 0.24.1 which is incompatible.
# Installing collected packages: numpy, pytz, six, python-dateutil, pandas, distro, dotnetcore2, azureml-dataprep-native, azureml-dataprep, applicationinsights, asn1crypto, pycparser, cffi, cryptography, pyasn1, pynacl, bcrypt, paramiko, jeepney, SecretStorage, ruamel.yaml, pyopenssl, pyyaml, chardet, idna, urllib3, certifi, requests, azure-common, oauthlib, requests-oauthlib, isodate, msrest, PyJWT, adal, msrestazure, azure-mgmt-storage, pathspec, backports.weakref, backports.tempfile, websocket-client, docker-pycreds, docker, azure-nspkg, azure-mgmt-nspkg, azure-mgmt-keyvault, ndg-httpsclient, contextlib2, azure-mgmt-resource, azure-mgmt-authorization, jmespath, azure-mgmt-containerregistry, azure-graphrbac, jsonpickle, azureml-core, azureml-telemetry, azureml-train-restclients-hyperdrive, azureml-train-core, azureml-train, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, scikit-learn, scipy, sklearn-pandas, dill, wheel, gast, keras-preprocessing, setuptools, protobuf, markdown, werkzeug, grpcio, tensorboard, h5py, keras-applications, termcolor, absl-py, astor, tensorflow, python-easyconfig, JsonSir, pyrsistent, attrs, jsonschema, JsonForm, resource, lightgbm, azureml-train-automl, pickleshare, pygments, decorator, wcwidth, prompt-toolkit, ptyprocess, pexpect, ipython-genutils, traitlets, backcall, parso, jedi, ipython, jupyter-core, nbformat, pyzmq, tornado, jupyter-client, ipykernel, terminado, prometheus-client, MarkupSafe, jinja2, pandocfilters, entrypoints, testpath, mistune, webencodings, bleach, defusedxml, nbconvert, Send2Trash, notebook, widgetsnbextension, ipywidgets, azureml-widgets, azureml-contrib-notebook, azureml-sdk, pyparsing, cycler, kiwisolver, matplotlib
# Successfully installed JsonForm-0.0.2 JsonSir-0.0.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.1 Send2Trash-1.5.0 absl-py-0.7.0 adal-1.2.1 applicationinsights-0.11.7 asn1crypto-0.24.0 astor-0.7.1 attrs-19.1.0 azure-common-1.1.18 azure-graphrbac-0.53.0 azure-mgmt-authorization-0.51.1 azure-mgmt-containerregistry-2.7.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-nspkg-3.0.2 azure-mgmt-resource-2.1.0 azure-mgmt-storage-3.1.1 azure-nspkg-3.0.2 azureml-contrib-notebook-1.0.17 azureml-core-1.0.17.1 azureml-dataprep-1.0.16 azureml-dataprep-native-11.2.2 azureml-pipeline-1.0.17 azureml-pipeline-core-1.0.17 azureml-pipeline-steps-1.0.17 azureml-sdk-1.0.17 azureml-telemetry-1.0.17 azureml-train-1.0.17 azureml-train-automl-1.0.17.1 azureml-train-core-1.0.17 azureml-train-restclients-hyperdrive-1.0.17 azureml-widgets-1.0.17 backcall-0.1.0 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.1.6 bleach-3.1.0 certifi-2018.11.29 cffi-1.12.2 chardet-3.0.4 contextlib2-0.5.5 cryptography-2.5 cycler-0.10.0 decorator-4.3.2 defusedxml-0.5.0 dill-0.2.9 distro-1.4.0 docker-3.7.0 docker-pycreds-0.4.0 dotnetcore2-2.1.7 entrypoints-0.3 gast-0.2.2 grpcio-1.19.0 h5py-2.9.0 idna-2.8 ipykernel-5.1.0 ipython-7.3.0 ipython-genutils-0.2.0 ipywidgets-7.4.2 isodate-0.6.0 jedi-0.13.3 jeepney-0.4 jinja2-2.10 jmespath-0.9.4 jsonpickle-1.1 jsonschema-3.0.1 jupyter-client-5.2.4 jupyter-core-4.4.0 keras-applications-1.0.7 keras-preprocessing-1.0.9 kiwisolver-1.0.1 lightgbm-2.2.1 markdown-3.0.1 matplotlib-3.0.3 mistune-0.8.4 msrest-0.6.4 msrestazure-0.6.0 nbconvert-5.4.1 nbformat-4.4.0 ndg-httpsclient-0.5.1 notebook-5.7.5 numpy-1.16.2 oauthlib-3.0.1 pandas-0.24.1 pandocfilters-1.4.2 paramiko-2.4.2 parso-0.3.4 pathspec-0.5.9 pexpect-4.6.0 pickleshare-0.7.5 prometheus-client-0.6.0 prompt-toolkit-2.0.9 protobuf-3.7.0 ptyprocess-0.6.0 pyasn1-0.4.5 pycparser-2.19 pygments-2.3.1 pynacl-1.3.0 pyopenssl-19.0.0 pyparsing-2.3.1 pyrsistent-0.14.11 python-dateutil-2.8.0 python-easyconfig-0.1.7 pytz-2018.9 pyyaml-3.13 pyzmq-18.0.1 requests-2.21.0 requests-oauthlib-1.2.0 resource-0.2.1 ruamel.yaml-0.15.51 scikit-learn-0.19.1 scipy-1.1.0 setuptools-40.8.0 six-1.12.0 sklearn-pandas-1.7.0 tensorboard-1.12.2 tensorflow-1.12.0 termcolor-1.1.0 terminado-0.8.1 testpath-0.4.2 tornado-6.0.1 traitlets-4.3.2 urllib3-1.24.1 wcwidth-0.1.7 webencodings-0.5.1 websocket-client-0.55.0 werkzeug-0.14.1 wheel-0.30.0 widgetsnbextension-3.4.2

# %%
import azureml.dataprep as dprep
import azureml.core
import pandas as pd
import logging
import os
from azureml.core.workspace import Workspace
from sklearn.model_selection import train_test_split
from azureml.train.automl import AutoMLConfig
from azureml.core.experiment import Experiment

# %% [markdown]
# CSVファイルもdprepをデータフレームではなく独自のデータフロー型に変換する

# %%
df_raw = dprep.auto_read_file(path="./32_Shimane Prefecture_20171_20182.csv")

# %%
display(df_raw.head(5))
# Out:
#     No         種類   地域  市区町村コード 都道府県名 市区町村名  地区名 最寄駅：名称 最寄駅：距離（分）    取引価格（総額）  \
# 0 1.00     宅地(土地)  住宅地 32201.00   島根県   松江市  秋鹿町    秋鹿町         4  5200000.00
# 1 2.00         林地      32201.00   島根県   松江市  秋鹿町                     25000.00
# 2 3.00  宅地(土地と建物)  住宅地 32201.00   島根県   松江市  上乃木     乃木        19 25000000.00
# 3 4.00     宅地(土地)  住宅地 32201.00   島根県   松江市  上乃木     松江   30分?60分  2000000.00
# 4 5.00  宅地(土地と建物)  住宅地 32201.00   島根県   松江市  上乃木     松江   30分?60分 28000000.00
#
#    ...  今後の利用目的 前面道路：方位 前面道路：種類  前面道路：幅員（ｍ）          都市計画 建ぺい率（％）  容積率（％）  \
# 0  ...       住宅       東      市道       11.00       市街化調整区域   70.00  200.00
# 1  ...                                  nan                   nan     nan
# 2  ...       住宅       南      市道        6.00  第２種中高層住居専用地域   60.00  200.00
# 3  ...      その他       北      市道        2.30       第１種住居地域   60.00  200.00
# 4  ...       住宅      南東      市道        4.00       第１種住居地域   60.00  200.00
#
#          取引時点 改装 取引の事情等
# 0  平成29年第１四半期
# 1  平成30年第２四半期
# 2  平成29年第４四半期
# 3  平成30年第２四半期
# 4  平成30年第２四半期
#
# [5 rows x 30 columns]

# %% [markdown]
# カラムの内容を自動で分析する

# %%
type_infer = df_raw.builders.set_column_types()

# %%
type_infer.learn()

# %%
type_converted_df = type_infer.to_dataflow()

# %%
type_converted_df.get_profile()
# Out:
# ColumnProfile:
#     column_name: No
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 3132.0
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 3.632
#            1%: 313.70000000000005
#            5%: 312.5
#           25%: 783.5
#           50%: 1566.5
#           75%: 2349.5
#           95%: 2975.9
#           99%: 3101.1799999999994
#         99.9%: 3129.368
#
#     mean: 1566.5
#     std: 904.2748475988924
#     variance: 817713.0
#     skewness: 0.0
#     kurtosis: -1.2011494862968426
#
# ColumnProfile:
#     column_name: 種類
#     type: FieldType.STRING
#
#     min: 中古マンション等
#     max: 農地
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 地域
#     type: FieldType.STRING
#
#     min:
#     max: 工業地
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1218.0
#
#
# ColumnProfile:
#     column_name: 市区町村コード
#     type: FieldType.DECIMAL
#
#     min: 32201.0
#     max: 32528.0
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 32201.0
#            1%: 32201.0
#            5%: 32201.0
#           25%: 32202.0
#           50%: 32203.0
#           75%: 32206.0
#           95%: 32502.715692307695
#           99%: 32528.0
#         99.9%: 32528.0
#
#     mean: 32233.847062579815
#     std: 86.29786521342828
#     variance: 7447.321540395035
#     skewness: 2.6455361631710685
#     kurtosis: 5.392909408783456
#
# ColumnProfile:
#     column_name: 都道府県名
#     type: FieldType.STRING
#
#     min: 島根県
#     max: 島根県
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 市区町村名
#     type: FieldType.STRING
#
#     min: 仁多郡奥出雲町
#     max: 鹿足郡津和野町
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 地区名
#     type: FieldType.STRING
#
#     min: あけぼの西町
#     max: （大字なし）
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 最寄駅：名称
#     type: FieldType.STRING
#
#     min:
#     max: 高浜(島根)
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1354.0
#
#
# ColumnProfile:
#     column_name: 最寄駅：距離（分）
#     type: FieldType.STRING
#
#     min:
#     max: 9
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1356.0
#
#
# ColumnProfile:
#     column_name: 取引価格（総額）
#     type: FieldType.DECIMAL
#
#     min: 1200.0
#     max: 500000000.0
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 3800.8
#            1%: 94716.80161943322
#            5%: 87947.36842105264
#           25%: 541006.3486616336
#           50%: 3263428.5714285714
#           75%: 9240196.078431372
#           95%: 31496491.22807013
#           99%: 81016666.66666646
#         99.9%: 207359999.99999878
#
#     mean: 8545262.931034483
#     std: 19720974.620889436
#     variance: 388916839997765.25
#     skewness: 11.429190991753002
#     kurtosis: 221.26223453033913
#
# ColumnProfile:
#     column_name: 坪単価
#     type: FieldType.DECIMAL
#
#     min: 130.0
#     max: 890000.0
#     count: 3132.0
#     missing_count: 1884.0
#     not_missing_count: 1248.0
#     percent_missing: 0.6015325670498084
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 556.36
#            1%: 22361.111111111113
#            5%: 21833.333333333332
#           25%: 41948.56459330144
#           50%: 79715.78947368421
#           75%: 120000.0
#           95%: 220000.0
#           99%: 318079.9999999999
#         99.9%: 538439.9999999778
#
#     mean: 90779.93589743572
#     std: 68450.67226665423
#     variance: 4685494533.7569065
#     skewness: 2.385209706515534
#     kurtosis: 16.171091705812177
#
# ColumnProfile:
#     column_name: 間取り
#     type: FieldType.STRING
#
#     min:
#     max: ４ＬＤＫ
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 3096.0
#
#
# ColumnProfile:
#     column_name: 面積（㎡）
#     type: FieldType.STRING
#
#     min: 100
#     max: 990
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 取引価格（㎡単価）
#     type: FieldType.DECIMAL
#
#     min: 38.0
#     max: 270000.0
#     count: 3132.0
#     missing_count: 1884.0
#     not_missing_count: 1248.0
#     percent_missing: 0.6015325670498084
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 166.656
#            1%: 6778.0
#            5%: 6620.0
#           25%: 12714.285714285714
#           50%: 24000.0
#           75%: 36681.81818181818
#           95%: 67000.0
#           99%: 95808.0
#         99.9%: 165279.99999999336
#
#     mean: 27491.769230769187
#     std: 20747.214933673382
#     variance: 430446927.5040398
#     skewness: 2.3934461457025353
#     kurtosis: 16.27101706281495
#
# ColumnProfile:
#     column_name: 土地の形状
#     type: FieldType.STRING
#
#     min:
#     max: 長方形
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1218.0
#
#
# ColumnProfile:
#     column_name: 間口
#     type: FieldType.STRING
#
#     min:
#     max: 9.9
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1386.0
#
#
# ColumnProfile:
#     column_name: 延床面積（㎡）
#     type: FieldType.DECIMAL
#
#     min: 15.0
#     max: 1900.0
#     count: 3132.0
#     missing_count: 2507.0
#     not_missing_count: 625.0
#     percent_missing: 0.8004469987228607
#     error_count: 4.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 16.21
#            1%: 70.0
#            5%: 70.0
#           25%: 95.0
#           50%: 124.2
#           75%: 179.921875
#           95%: 619.6249999999995
#           99%: 1228.9999999999964
#         99.9%: 1887.900000000002
#
#     mean: 191.5780998389695
#     std: 221.4474140671521
#     variance: 49038.957197028714
#     skewness: 3.939661382468158
#     kurtosis: 18.79508953549368
#
# ColumnProfile:
#     column_name: 建築年
#     type: FieldType.STRING
#
#     min:
#     max: 昭和63年
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 2546.0
#
#
# ColumnProfile:
#     column_name: 建物の構造
#     type: FieldType.STRING
#
#     min:
#     max: ＳＲＣ
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 2491.0
#
#
# ColumnProfile:
#     column_name: 用途
#     type: FieldType.STRING
#
#     min:
#     max: 駐車場
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 2489.0
#
#
# ColumnProfile:
#     column_name: 今後の利用目的
#     type: FieldType.STRING
#
#     min:
#     max: 店舗
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1752.0
#
#
# ColumnProfile:
#     column_name: 前面道路：方位
#     type: FieldType.STRING
#
#     min:
#     max: 西
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1218.0
#
#
# ColumnProfile:
#     column_name: 前面道路：種類
#     type: FieldType.STRING
#
#     min:
#     max: 都道
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1252.0
#
#
# ColumnProfile:
#     column_name: 前面道路：幅員（ｍ）
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 30.0
#     count: 3132.0
#     missing_count: 1255.0
#     not_missing_count: 1877.0
#     percent_missing: 0.4007024265644955
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 3.4943434343434343
#            5%: 3.481818181818182
#           25%: 4.0
#           50%: 6.0
#           75%: 6.873333333333333
#           95%: 13.990659340659338
#           99%: 20.067785714285716
#         99.9%: 28.623000000000047
#
#     mean: 6.395524773574854
#     std: 3.584384993631162
#     variance: 12.847815782568263
#     skewness: 2.13448283917768
#     kurtosis: 6.322284190572848
#
# ColumnProfile:
#     column_name: 都市計画
#     type: FieldType.STRING
#
#     min:
#     max: 都市計画区域外
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1182.0
#
#
# ColumnProfile:
#     column_name: 建ぺい率（％）
#     type: FieldType.DECIMAL
#
#     min: 40.0
#     max: 80.0
#     count: 3132.0
#     missing_count: 1375.0
#     not_missing_count: 1757.0
#     percent_missing: 0.4390166028097063
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 50.0
#            1%: 60.0
#            5%: 60.0
#           25%: 60.0
#           50%: 60.0
#           75%: 70.0
#           95%: 80.0
#           99%: 80.0
#         99.9%: 80.0
#
#     mean: 65.33295389869085
#     std: 7.46785907184208
#     variance: 55.76891911689405
#     skewness: 0.611881257701653
#     kurtosis: -0.39656571873234014
#
# ColumnProfile:
#     column_name: 容積率（％）
#     type: FieldType.DECIMAL
#
#     min: 80.0
#     max: 1300.0
#     count: 3132.0
#     missing_count: 1375.0
#     not_missing_count: 1757.0
#     percent_missing: 0.4390166028097063
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 80.0
#            1%: 200.0
#            5%: 200.0
#           25%: 200.0
#           50%: 200.0
#           75%: 200.0
#           95%: 400.0
#           99%: 500.0
#         99.9%: 500.0
#
#     mean: 210.75128059191763
#     std: 69.72369936950544
#     variance: 4861.394253769173
#     skewness: 4.001204996895827
#     kurtosis: 38.27261739845077
#
# ColumnProfile:
#     column_name: 取引時点
#     type: FieldType.STRING
#
#     min: 平成29年第１四半期
#     max: 平成30年第２四半期
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 改装
#     type: FieldType.STRING
#
#     min:
#     max: 未改装
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 3097.0
#
#
# ColumnProfile:
#     column_name: 取引の事情等
#     type: FieldType.STRING
#
#     min:
#     max: 隣地の購入、関係者間取引
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 3052.0

# %% [markdown]
# データフレームをパッケージ化する

# %%
file_path = os.path.join(os.getcwd(), "dflows.dprep")

package = dprep.Package([type_converted_df])
package.save(file_path)
# Out:
# Package
#   name: None
#   path: /home/nbuser/library/dflows.dprep
#   dataflows: [
#     Dataflow {
#       name: 32_Shimane Prefecture_20171_20182
#       steps: 5
#     },
#   ]

# %% [markdown]
# # トレーニング
# 最初に利用するWorkspaceの情報を取得する。
# 実行する時に一度Azureにログインを行う。

# %%
ws = Workspace.from_config()
experiment_name = 'automated-ml-regression'
project_folder = './automated-ml-regression'

output = {}
output['SDK version'] = azureml.core.VERSION
output['Subscription ID'] = ws.subscription_id
output['Workspace'] = ws.name
output['Resource Group'] = ws.resource_group
output['Location'] = ws.location
output['Project Directory'] = project_folder
pd.set_option('display.max_colwidth', -1)
pd.DataFrame(data=output, index=['']).T

# %%
file_path = os.path.join(os.getcwd(), "dflows.dprep")

package_saved = dprep.Package.open(file_path)
dflow_prepared = package_saved.dataflows[0]
dflow_prepared.get_profile()
# Out:
# ColumnProfile:
#     column_name: No
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 3132.0
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 3.632
#            1%: 313.70000000000005
#            5%: 312.5
#           25%: 783.5
#           50%: 1566.5
#           75%: 2349.5
#           95%: 2975.9
#           99%: 3101.1799999999994
#         99.9%: 3129.368
#
#     mean: 1566.5
#     std: 904.2748475988924
#     variance: 817713.0
#     skewness: 0.0
#     kurtosis: -1.2011494862968426
#
# ColumnProfile:
#     column_name: 種類
#     type: FieldType.STRING
#
#     min: 中古マンション等
#     max: 農地
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 地域
#     type: FieldType.STRING
#
#     min:
#     max: 工業地
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1218.0
#
#
# ColumnProfile:
#     column_name: 市区町村コード
#     type: FieldType.DECIMAL
#
#     min: 32201.0
#     max: 32528.0
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 32201.0
#            1%: 32201.0
#            5%: 32201.0
#           25%: 32202.0
#           50%: 32203.0
#           75%: 32206.0
#           95%: 32502.715692307695
#           99%: 32528.0
#         99.9%: 32528.0
#
#     mean: 32233.847062579815
#     std: 86.29786521342828
#     variance: 7447.321540395035
#     skewness: 2.6455361631710685
#     kurtosis: 5.392909408783456
#
# ColumnProfile:
#     column_name: 都道府県名
#     type: FieldType.STRING
#
#     min: 島根県
#     max: 島根県
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 市区町村名
#     type: FieldType.STRING
#
#     min: 仁多郡奥出雲町
#     max: 鹿足郡津和野町
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 地区名
#     type: FieldType.STRING
#
#     min: あけぼの西町
#     max: （大字なし）
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 最寄駅：名称
#     type: FieldType.STRING
#
#     min:
#     max: 高浜(島根)
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1354.0
#
#
# ColumnProfile:
#     column_name: 最寄駅：距離（分）
#     type: FieldType.STRING
#
#     min:
#     max: 9
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1356.0
#
#
# ColumnProfile:
#     column_name: 取引価格（総額）
#     type: FieldType.DECIMAL
#
#     min: 1200.0
#     max: 500000000.0
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 3800.8
#            1%: 94716.80161943322
#            5%: 87947.36842105264
#           25%: 541006.3486616336
#           50%: 3263428.5714285714
#           75%: 9240196.078431372
#           95%: 31496491.22807013
#           99%: 81016666.66666646
#         99.9%: 207359999.99999878
#
#     mean: 8545262.931034483
#     std: 19720974.620889436
#     variance: 388916839997765.25
#     skewness: 11.429190991753002
#     kurtosis: 221.26223453033913
#
# ColumnProfile:
#     column_name: 坪単価
#     type: FieldType.DECIMAL
#
#     min: 130.0
#     max: 890000.0
#     count: 3132.0
#     missing_count: 1884.0
#     not_missing_count: 1248.0
#     percent_missing: 0.6015325670498084
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 556.36
#            1%: 22361.111111111113
#            5%: 21833.333333333332
#           25%: 41948.56459330144
#           50%: 79715.78947368421
#           75%: 120000.0
#           95%: 220000.0
#           99%: 318079.9999999999
#         99.9%: 538439.9999999778
#
#     mean: 90779.93589743572
#     std: 68450.67226665423
#     variance: 4685494533.7569065
#     skewness: 2.385209706515534
#     kurtosis: 16.171091705812177
#
# ColumnProfile:
#     column_name: 間取り
#     type: FieldType.STRING
#
#     min:
#     max: ４ＬＤＫ
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 3096.0
#
#
# ColumnProfile:
#     column_name: 面積（㎡）
#     type: FieldType.STRING
#
#     min: 100
#     max: 990
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 取引価格（㎡単価）
#     type: FieldType.DECIMAL
#
#     min: 38.0
#     max: 270000.0
#     count: 3132.0
#     missing_count: 1884.0
#     not_missing_count: 1248.0
#     percent_missing: 0.6015325670498084
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 166.656
#            1%: 6778.0
#            5%: 6620.0
#           25%: 12714.285714285714
#           50%: 24000.0
#           75%: 36681.81818181818
#           95%: 67000.0
#           99%: 95808.0
#         99.9%: 165279.99999999336
#
#     mean: 27491.769230769187
#     std: 20747.214933673382
#     variance: 430446927.5040398
#     skewness: 2.3934461457025353
#     kurtosis: 16.27101706281495
#
# ColumnProfile:
#     column_name: 土地の形状
#     type: FieldType.STRING
#
#     min:
#     max: 長方形
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1218.0
#
#
# ColumnProfile:
#     column_name: 間口
#     type: FieldType.STRING
#
#     min:
#     max: 9.9
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1386.0
#
#
# ColumnProfile:
#     column_name: 延床面積（㎡）
#     type: FieldType.DECIMAL
#
#     min: 15.0
#     max: 1900.0
#     count: 3132.0
#     missing_count: 2507.0
#     not_missing_count: 625.0
#     percent_missing: 0.8004469987228607
#     error_count: 4.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 16.21
#            1%: 70.0
#            5%: 70.0
#           25%: 95.0
#           50%: 124.2
#           75%: 179.921875
#           95%: 619.6249999999995
#           99%: 1228.9999999999964
#         99.9%: 1887.900000000002
#
#     mean: 191.5780998389695
#     std: 221.4474140671521
#     variance: 49038.957197028714
#     skewness: 3.939661382468158
#     kurtosis: 18.79508953549368
#
# ColumnProfile:
#     column_name: 建築年
#     type: FieldType.STRING
#
#     min:
#     max: 昭和63年
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 2546.0
#
#
# ColumnProfile:
#     column_name: 建物の構造
#     type: FieldType.STRING
#
#     min:
#     max: ＳＲＣ
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 2491.0
#
#
# ColumnProfile:
#     column_name: 用途
#     type: FieldType.STRING
#
#     min:
#     max: 駐車場
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 2489.0
#
#
# ColumnProfile:
#     column_name: 今後の利用目的
#     type: FieldType.STRING
#
#     min:
#     max: 店舗
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1752.0
#
#
# ColumnProfile:
#     column_name: 前面道路：方位
#     type: FieldType.STRING
#
#     min:
#     max: 西
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1218.0
#
#
# ColumnProfile:
#     column_name: 前面道路：種類
#     type: FieldType.STRING
#
#     min:
#     max: 都道
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1252.0
#
#
# ColumnProfile:
#     column_name: 前面道路：幅員（ｍ）
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 30.0
#     count: 3132.0
#     missing_count: 1255.0
#     not_missing_count: 1877.0
#     percent_missing: 0.4007024265644955
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 3.4943434343434343
#            5%: 3.481818181818182
#           25%: 4.0
#           50%: 6.0
#           75%: 6.873333333333333
#           95%: 13.990659340659338
#           99%: 20.067785714285716
#         99.9%: 28.623000000000047
#
#     mean: 6.395524773574854
#     std: 3.584384993631162
#     variance: 12.847815782568263
#     skewness: 2.13448283917768
#     kurtosis: 6.322284190572848
#
# ColumnProfile:
#     column_name: 都市計画
#     type: FieldType.STRING
#
#     min:
#     max: 都市計画区域外
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1182.0
#
#
# ColumnProfile:
#     column_name: 建ぺい率（％）
#     type: FieldType.DECIMAL
#
#     min: 40.0
#     max: 80.0
#     count: 3132.0
#     missing_count: 1375.0
#     not_missing_count: 1757.0
#     percent_missing: 0.4390166028097063
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 50.0
#            1%: 60.0
#            5%: 60.0
#           25%: 60.0
#           50%: 60.0
#           75%: 70.0
#           95%: 80.0
#           99%: 80.0
#         99.9%: 80.0
#
#     mean: 65.33295389869085
#     std: 7.46785907184208
#     variance: 55.76891911689405
#     skewness: 0.611881257701653
#     kurtosis: -0.39656571873234014
#
# ColumnProfile:
#     column_name: 容積率（％）
#     type: FieldType.DECIMAL
#
#     min: 80.0
#     max: 1300.0
#     count: 3132.0
#     missing_count: 1375.0
#     not_missing_count: 1757.0
#     percent_missing: 0.4390166028097063
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 80.0
#            1%: 200.0
#            5%: 200.0
#           25%: 200.0
#           50%: 200.0
#           75%: 200.0
#           95%: 400.0
#           99%: 500.0
#         99.9%: 500.0
#
#     mean: 210.75128059191763
#     std: 69.72369936950544
#     variance: 4861.394253769173
#     skewness: 4.001204996895827
#     kurtosis: 38.27261739845077
#
# ColumnProfile:
#     column_name: 取引時点
#     type: FieldType.STRING
#
#     min: 平成29年第１四半期
#     max: 平成30年第２四半期
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: 改装
#     type: FieldType.STRING
#
#     min:
#     max: 未改装
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 3097.0
#
#
# ColumnProfile:
#     column_name: 取引の事情等
#     type: FieldType.STRING
#
#     min:
#     max: 隣地の購入、関係者間取引
#     count: 3132.0
#     missing_count: 0.0
#     not_missing_count: 3132.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 3052.0

# %%
dflow_X = dflow_prepared.keep_columns(['市区町村コード','間取り', '改装','前面道路：幅員（ｍ）', '延床面積（㎡）'])

# %%
dflow_y = dflow_prepared.keep_columns('取引価格（総額）')

# %%
x_df = dflow_X.to_pandas_dataframe()
y_df = dflow_y.to_pandas_dataframe()

x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2, random_state=223)
y_train.values.flatten()
# Out:
# array([1.1e+04, 1.9e+04, 8.4e+06, ..., 3.4e+07, 8.2e+05, 2.3e+07])

# %%
automl_settings = {
    "iteration_timeout_minutes" : 10,
    "iterations" : 30,
    "primary_metric" : 'spearman_correlation',
    "preprocess" : True,
    "verbosity" : logging.INFO,
    "n_cross_validations": 5
}

# %%
automated_ml_config = AutoMLConfig(task = 'regression',
                             debug_log = 'automated_ml_errors.log',
                             path = project_folder,
                             X = x_train.values,
                             y = y_train.values.flatten(),
                             **automl_settings)

# %%
experiment=Experiment(ws, experiment_name)
local_run = experiment.submit(automated_ml_config, show_output=True)
# Out:
# Running on local machine
# Parent Run ID: AutoML_ae8b2755-4234-448b-8dbd-0d7a9a13955a
# ********************************************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# SAMPLING %: Percent of the training data to sample.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ********************************************************************************************************************
#
#  ITERATION   PIPELINE                                       SAMPLING %  DURATION      METRIC      BEST
#          0   MaxAbsScaler RandomForest                      100.0000    0:00:48       0.7276    0.7276
#          1   StandardScalerWrapper DecisionTree             100.0000    0:01:12       0.7324    0.7324
#          2   StandardScalerWrapper LightGBM                 100.0000    0:00:51       0.7620    0.7620
#          3   StandardScalerWrapper LightGBM                 100.0000    0:00:50       0.7451    0.7620
#          4   StandardScalerWrapper DecisionTree             100.0000    0:00:46       0.7334    0.7620
#          5   MaxAbsScaler LightGBM                          100.0000    0:00:47       0.7561    0.7620
#          6   StandardScalerWrapper DecisionTree             100.0000    0:00:40       0.7414    0.7620
#          7   MaxAbsScaler ExtremeRandomTrees                100.0000    0:00:44       0.7418    0.7620
#          8   StandardScalerWrapper GradientBoosting         100.0000    0:00:43       0.7373    0.7620
#          9   MaxAbsScaler LightGBM                          100.0000    0:00:42       0.7495    0.7620
#         10   MaxAbsScaler RandomForest                      100.0000    0:00:44       0.7538    0.7620
#         11   MaxAbsScaler ExtremeRandomTrees                100.0000    0:00:44       0.7515    0.7620
#         12   MaxAbsScaler SGD                               100.0000    0:00:44       0.6669    0.7620
#         13   MaxAbsScaler LightGBM                          100.0000    0:00:42       0.7391    0.7620
#         14   MaxAbsScaler LightGBM                          100.0000    0:00:45       0.7468    0.7620
#         15   MaxAbsScaler SGD                               100.0000    0:00:37      -0.6139    0.7620
#         16   StandardScalerWrapper LightGBM                 100.0000    0:00:37       0.7478    0.7620
#         17   StandardScalerWrapper LightGBM                 100.0000    0:00:38       0.7195    0.7620
#         18   StandardScalerWrapper DecisionTree             100.0000    0:00:38       0.7224    0.7620
#         19   MaxAbsScaler LightGBM                          100.0000    0:00:44       0.7150    0.7620
#         20   StandardScalerWrapper GradientBoosting         100.0000    0:00:55       0.7604    0.7620
#         21   MaxAbsScaler RandomForest                      100.0000    0:01:08       0.7135    0.7620
#         22   MaxAbsScaler DecisionTree                      100.0000    0:00:44       0.7288    0.7620
#         23   MaxAbsScaler ExtremeRandomTrees                100.0000    0:01:38       0.7576    0.7620
#         24   MaxAbsScaler ExtremeRandomTrees                100.0000    0:03:38       0.7253    0.7620
#         25   MaxAbsScaler LightGBM                          100.0000    0:00:47       0.7131    0.7620
#         26   MaxAbsScaler RandomForest                      100.0000    0:00:45       0.7567    0.7620
#         27   StandardScalerWrapper DecisionTree             100.0000    0:00:42       0.7268    0.7620
#         28   MaxAbsScaler LightGBM                          100.0000    0:00:52       0.7171    0.7620
#         29   Ensemble                                       100.0000    0:02:04       0.7674    0.7674
